# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukasz2107/learning/blob/main/SVM_Support_Vector_Machines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Zrzut ekranu 2023-11-03 160824.png](data:image/png;base64,...)

# %% [markdown]
# the distance should be as big as possible. example of **hard margin** there are no points between

# %% [markdown]
# ![Zrzut ekranu 2023-11-03 161812.png](data:image/png;base64,...)

# %% [markdown]
# KERNELS - its a function that makes the 3d from 2d. then we can split our data easier

# %% [markdown]
# ![Zrzut ekranu 2023-11-03 162255.png](data:image/png;base64,...)

# %% [markdown]
# example of **soft margin**. we allow some points to be between margin and other data points

# %%
import sklearn
from sklearn import datasets
from sklearn import svm

# to compare with KNN algorithm
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

# %%
cancer = datasets.load_breast_cancer() # dataset from sklearn

#print(cancer.feature_names)
#print(cancer.target_names)

x = cancer.data
y = cancer.target

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, train_size=0.2)
classes = ['malignant' 'benign']

# %%
clf = svm.SVC(kernel = 'linear', C=2)
# SVC - support vector classification, kernel = linear, poly(more advanced)
# C - soft margin, default = 1, 2 - double the points, hard margin = 0

clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
acc = metrics.accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.9232456140350878

# %%
#compare to knn
clf = KNeighborsClassifier(n_neighbors=7)
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
acc = metrics.accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.8925438596491229
