# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukasz2107/learning/blob/main/MLlearning_TWT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as pyplot
import pickle
from matplotlib import style

# %% [markdown]
# read csv and choose correct columns - https://colab.research.google.com/drive/1A_6dBwCb35P__qWqtjkKduCyZ-TDyP48?authuser=1

# %%
data = pd.read_csv('student-mat.csv', sep=';')
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
pyplot.scatter(data["G3"], data["G2"])

# %% [markdown]
# we want to predict G3 so X = data without G3, Y = only G3 data

# %%
predict = "G3"
x = np.array(data.drop([predict], 1)) #drop deletes data, 1 is axis
y = np.array(data["G3"])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)

# you always get 4 parameters - x_train, x_test, y_train, y_test as an output

# x train - parameteres which contains every other value except G3
# x test - parameteres of x_train but to test
# y_train - parameters which contains only G3, actual values of G3
# y_test - parameters of y_train but to test, actual values of G3

# test_size is the size of x_test value, it means that 20 % of the whole dataset is for testing
# x_train contains the values that are random, if you dont want to change it, use random_state=int

'''
best = 0
for _ in range(500):

  linear = linear_model.LinearRegression()
  linear.fit(x_train, y_train) # data to train a model, obviously contains only training data

  acc = linear.score(x_test, y_test) # to verify your accuracy

  if float(acc) > float(best):
    best = acc
    print(best)
    print(acc)
    with open("studentmodel.pickle", "wb") as f:
      pickle.dump(linear, f)
'''
# Out:
# 0.935355610129003
# 0.935355610129003
# <ipython-input-21-9da8780a7a15>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = np.array(data.drop([predict], 1)) #drop deletes data, 1 is axis

# %%
pickle_in = open("studentmodel.pickle", "rb")
linear = pickle.load(pickle_in)

print("Co", linear.coef_) # coefficient - współczynnik a
print("intercept:", linear.intercept_) # intercept - współczynnik b

predictions = linear.predict(x_test)

for x in range(len(predictions)):
  print(predictions[x], x_test[x], y_test[x])

style.use("ggplot")
pyplot.scatter(data["G1"], data["G3"])
pyplot.xlabel("G1")
pyplot.ylabel("Final Grade")
pyplot.show()
# Out:
# Co [ 0.14793339  0.99605769 -0.18198087 -0.31369453  0.04670407]
# intercept: -1.6881731822677857
# 13.997787629808476 [13 14  1  0  0] 14
# 10.625175058967264 [11 11  2  0  2] 10
# 4.905219677473884 [6 6 2 0 2] 6
# 11.1934450722999 [12 11  2  0 11] 11
# -1.1483148729049368 [7 0 1 1 0] 0
# 15.10773122509881 [15 15  2  0  0] 15
# 16.399655688945916 [17 16  2  0  0] 16
# 14.95979783755038 [14 15  2  0  0] 15
# 12.765223824016186 [12 13  2  0  2] 13
# 11.89452336972357 [10  9  2  0 75] 9
# 10.349786051347333 [11 11  3  0  0] 10
# 14.791386682525015 [11 15  1  0  2] 15
# 14.845911931010288 [12 15  1  0  0] 15
# 8.705990053052998 [9 9 1 0 6] 10
# 4.002570127786795 [6 5 2 0 4] 6
# 6.792089292215055 [ 6  8  1  3 16] 8
# 9.100100376782558 [11  9  2  0 12] 9
# 15.201139364161968 [15 15  2  0  2] 16
# 6.383960419447305 [8 7 2 0 6] 9
# 10.167805182790563 [11 11  4  0  0] 11
# -1.905809570469626 [4 0 1 2 0] 0
# 5.146561204085472 [7 6 2 0 4] 6
# 13.325672658395126 [12 13  2  0 14] 12
# 9.304038523681358 [10 10  4  0  6] 11
# 14.175869603972926 [16 14  4  0  6] 15
# 8.049517439547039 [10  8  2  0 14] 9
# 5.248239357609106 [7 7 2 3 5] 7
# -2.0715707178405913 [5 0 1 3 0] 0
# 3.502059314741085 [6 5 2 1 0] 0
# 19.5288884563901 [18 18  1  1 24] 18
# 14.239129156420065 [14 14  1  0  2] 14
# 15.820948856595724 [16 15  3  0 16] 15
# -0.6068485249053603 [11  0  3  0  0] 0
# 18.455967134070765 [18 18  4  0  6] 18
# 8.578534432981499 [10  9  2  0  4] 9
# 11.675757996202783 [12 12  2  0  0] 11
# 8.469483936010953 [8 9 2 0 8] 10
# 12.671815684953028 [12 13  2  0  0] 13
# 10.531766919904106 [11 11  2  0  0] 10
# 15.349072751710398 [16 15  2  0  2] 15
