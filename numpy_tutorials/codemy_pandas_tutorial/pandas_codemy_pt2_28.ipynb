# %% [markdown]
# <a href="https://colab.research.google.com/github/ukasz21/learning/blob/main/numpy_tutorials/codemy_pandas_tutorial/pandas_codemy_pt2_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **All important functions and methods:**
# ---
# - pd.Series()
# - pd.Dataframe()
# - pd.read_csv()
#   - df.head() - first 5 rows
#   - df.tail() - last 5 rows
#   - df.shape
#   - df.ndim - number of dimensions
#   - df.dtypes - data type of columns
#   - df.describe() - stats about data  ---> `df['radius_se'].describe()`  # describe a specific column
#   - `df['area_se'].value_counts()` - counts distinct values
#     - `df['area_se'].value_counts(ascending=True) ` - asc
#     - `df['area_se'].value_counts(dropna=False)`- shows NaN
#     - `df2['area_se'].value_counts(normalize=True)` - gives percentage
#     - `df2['area_se'].value_counts()[16.97]` - gives specific item
#     - `df2.groupby('area_se').size() - count unique values` - size
#     - `df2.groupby('area_se').count() - count unique values `- count
#   - `df2['nothingnew'] = [True] * len(df2)` - adding a new column
#   - `df2.insert(1, "new", [True]*len(df2), True)` # index, header, whats inside, allow duplicates  - adding new columns with insert
#   - `df3 = df2.assign(Horse=[False]*len(df2))` - add columns by creating a new dataframe
#   - `df2.drop("area_mean", axis=1)` - remove columns axis 1 (by default its 0)
#   - `df2.drop("area_mean", axis=1, inplace=True)` - removes it permanently (inplace = True)
#   - `df2.loc[2] `- grab row method 1
#   - `df2.iloc[1]` - grab row method 2 - index location
#   - `df2.loc[1, 'radius_mean']` - grab specific rows and columns
#   - `df2.loc[[1, 3], ['area_worst', 'radius_mean']]` - grab subsets
# ---
# CONDITIONS
#   - `df2 == "BROWN"` # condition if it equals BROWN
#   - `df2[df2 == 1]` - returns dataframe with data
#   - `df2[df2 == "BROWN"]["texture_mean"]` - run them on a column
#   - `df2[df2 == "BROWN"][["texture_mean", 'radius_mean']]` - return multiple columns
# ---
# CONDITIONS AND OR
#   - `df2[(df2['texture_mean'] == 17.77) & (df2['radius_mean'] == 20.57)]`
#   - `df2[(df2['texture_mean'] == 17.77) | (df2['radius_mean'] == 20.57)]`
#   you can use len() function to check
#
# ---
#   INDEX:
#   - `df2.set_index("nothing") # permanently - inplace=True`
#   - `df2.reset_index()`
#   - `df2.drop("nothing", axis=1)`
# ---
# DUMMY DATA:
# -
# ```
# # stuff = {'A': [1,2,3], "B": [4,np.nan,6], "C": [7,8,9], 'D': [10,11,12]}
# df2 = pd.DataFrame(stuff)
# ```
# - `df2.dropna() `- drop NaN rows
# - `df2.dropna(axis=1)` - drop NaN columns
# - `df2.dropna(thresh=2, axis=1)` - drop columns where is two NaN values
# - `df2.fillna(value="Bob")` - use it to set a new value to NaN object
# - `df2.fillna(value=df2['B'].mean())` - use math functions like mean(), min(), max()
# ---
# DATAFRAME GROUP BY:
# - `company = df2.groupby('Corporation')`
# - `company.sum()` # other: mean(), min(), max(), std(), var(), count(), describe()
#
# ---
# COUNT UNIQUE VALUES:
# - `df2["radius_mean"].value_counts()`
# - `pd.DataFrame(df2["radius_mean"].value_counts())` - making a dataframe
# - `df2["radius_mean"].unique()` - return only unique items
# - `pd.DataFrame(df2["radius_mean"].unique())` - making a dataframe
#
# ---
# FUNCTIONS:
# - basic function
# ```
# # def times1000(x):
#   return format(x * 1000, ',d')
# ```
# - `df3['Salary'].apply(times1000)` - apply the function
# - `pd.DataFrame(df3['Salary'].apply(times1000))` - use dataframe
# - `df3['Salary'].apply(lambda x: x * 1000)` - make a function using lambda
#
# ---
# FUNCTIONS - Multiple columns:
# - append to current DF
# ```
# # df3[['Corporation', 'Employees']] = df3[['Corporation', 'Employees']].apply(namer)
# df3
# ```
# - `df3[['Corporation', 'Employees']].apply(namer)` - apply to two columns
# -
# ```
# # df3[['Corporation', 'Employees']] = df3[['Corporation', 'Employees']].apply(namer)
# ```
# append to current dataframe
#
#
#
#
# ---
#
# **SORTING AND ORDERING DATA:**
# - `df3.sort_values("Salary")` - sort salaries
# - `df3.sort_values("Salary", ascending=False)` - sort from highest to lowest
# - `df3.sort_values("Corporation")` - sort alphabetically
#
# ---
# HISTOGRAMS WITH MATPLOTLIB:
# -
# ```
# import matplotlib.pyplot as plt
# from numpy.random import randn
# ```
#
# - `df4 = pd.DataFrame(randn(100, 4), columns=['Mon', 'Tues', "Wed", 'Thur'])` - create dataframe
# - `df4['Wed'].hist()` - create histogram
# - `df4['Wed'].hist(bins=50)` - histogram with smaller bins
# - `df4['Wed'].plot(kind='hist')` - another way without grid bars
# - `df4['Wed'].hist(bins=50, grid=False)` - without grid
# - `df4['Wed'].hist(bins=50, legend=True)` - with legend
#
# ---

# %% [markdown]
# # **PART2**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# pandas series - like a table column - I dimensional array holding any type of data

# %%
series = [5,6,7,3,2,5,1,9]
var = pd.Series(series)
var
# Out:
# 0    5
# 1    6
# 2    7
# 3    3
# 4    2
# 5    5
# 6    1
# 7    9
# dtype: int64

# %% [markdown]
# get specific value

# %%
series[2]
# Out:
# 7

# %% [markdown]
# labels using the index argument

# %%
index = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
var2 = pd.Series(series, index)
var2
# Out:
# A    5
# B    6
# C    7
# D    3
# E    2
# F    5
# G    1
# H    9
# dtype: int64

# %%
var2['B']
# Out:
# 6

# %% [markdown]
# key value dictonary

# %%
cars = {'tesla': 12, 'Mercedes': 42, 'BMW': 3}
var3 = pd.Series(cars)
var3
# Out:
# tesla       12
# Mercedes    42
# BMW          3
# dtype: int64

# %%
var3["tesla"]
# Out:
# 12

# %% [markdown]
# # **PART3**

# %% [markdown]
# data frame

# %%
from numpy.random import randn

# %%
data = randn(4, 3) #rows, cols
rows = ['A', 'B', 'C', 'D']
cols = ['Monday', 'Tuesday', 'Friday']

# %% [markdown]
# create data frame

# %%
df = pd.DataFrame(data, rows, cols)
df
# Out:
#      Monday   Tuesday    Friday
# A  0.680180  0.915107 -0.177734
# B -1.278321  0.100271  0.720724
# C  2.260094  0.527926  0.397570
# D  0.000682  0.672690  0.034544

# %% [markdown]
# **importing csv file**

# %%
 df2 = pd.read_csv('cancer.csv')
 df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# pull out rows

# %%
df2.loc[0]
# Out:
# diagnosis(1=m, 0=b)           1.000000
# radius_mean                  17.990000
# texture_mean                 10.380000
# perimeter_mean              122.800000
# area_mean                  1001.000000
# smoothness_mean               0.118400
# compactness_mean              0.277600
# concavity_mean                0.300100
# concave points_mean           0.147100
# symmetry_mean                 0.241900
# fractal_dimension_mean        0.078710
# radius_se                     1.095000
# texture_se                    0.905300
# perimeter_se                  8.589000
# area_se                     153.400000
# smoothness_se                 0.006399
# compactness_se                0.049040
# concavity_se                  0.053730
# concave points_se             0.015870
# symmetry_se                   0.030030
# fractal_dimension_se          0.006193
# radius_worst                 25.380000
# texture_worst                17.330000
# perimeter_worst             184.600000
# ...

# %% [markdown]
# pull out multiple rows

# %%
df2.loc[[0, 5]]
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0                    1        17.99         10.38          122.80     1001.0
# 5                    1        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001              0.14710
# 5           0.1278            0.1700          0.1578              0.08089
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
# 5         0.2087  ...         15.47          23.75            103.4
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 5       741.6            0.1791             0.5249           0.5355
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# ...

# %% [markdown]
# # **PART4**

# %% [markdown]
# grab first 5 rows

# %%
df2.head() # return first 5
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0                    1        17.99         10.38          122.80     1001.0
# 1                    1        20.57         17.77          132.90     1326.0
# 2                    1        19.69         21.25          130.00     1203.0
# 3                    1        11.42         20.38           77.58      386.1
# 4                    1        20.29         14.34          135.10     1297.0
#
#    ...  compactness_worst  concavity_worst  concave points_worst  \
# 0  ...             0.6656           0.7119                0.2654
# 1  ...             0.1866           0.2416                0.1860
# 2  ...             0.4245           0.4504                0.2430
# 3  ...             0.8663           0.6869                0.2575
# 4  ...             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# ...

# %% [markdown]
# grab certain number of first rows

# %%
df2.head(9)
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0                    1        17.99         10.38          122.80     1001.0
# 1                    1        20.57         17.77          132.90     1326.0
# 2                    1        19.69         21.25          130.00     1203.0
# 3                    1        11.42         20.38           77.58      386.1
# 4                    1        20.29         14.34          135.10     1297.0
# 5                    1        12.45         15.70           82.57      477.1
# 6                    1        18.25         19.98          119.60     1040.0
# 7                    1        13.71         20.83           90.20      577.9
# 8                    1        13.00         21.82           87.50      519.8
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# ...

# %% [markdown]
# grab last 5 rows

# %%
df2.tail()
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  symmetry_mean  ...  radius_worst  texture_worst  \
# 564              0.13890         0.1726  ...        25.450          26.40
# ...

# %%
df2.tail(8)
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 561                    0        11.20         29.37           70.67
# 562                    1        15.22         30.62          103.40
# 563                    1        20.92         25.09          143.00
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 561      386.0          0.07449           0.03558         0.00000
# 562      716.9          0.10480           0.20870         0.25500
# 563     1347.0          0.10990           0.22360         0.31740
# 564     1479.0          0.11100           0.11590         0.24390
# ...

# %% [markdown]
# get info about the dataframe

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis(1=m, 0=b)      569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# get shape of rows and columns

# %%
df2.shape
# Out:
# (569, 31)

# %% [markdown]
# get the number of dimensions

# %%
df2.ndim
# Out:
# 2

# %% [markdown]
# get the column datatypes

# %%
df2.dtypes
# Out:
# diagnosis(1=m, 0=b)          int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %% [markdown]
# get some statistics about data

# %%
df2.describe()
# Out:
#        diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# count           569.000000   569.000000    569.000000      569.000000
# mean              0.372583    14.127292     19.289649       91.969033
# std               0.483918     3.524049      4.301036       24.298981
# min               0.000000     6.981000      9.710000       43.790000
# 25%               0.000000    11.700000     16.170000       75.170000
# 50%               0.000000    13.370000     18.840000       86.240000
# 75%               1.000000    15.780000     21.800000      104.100000
# max               1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %% [markdown]
# describe a specific column

# %%
df2['radius_se'].describe()
# Out:
# count    569.000000
# mean       0.405172
# std        0.277313
# min        0.111500
# 25%        0.232400
# 50%        0.324200
# 75%        0.478900
# max        2.873000
# Name: radius_se, dtype: float64

# %% [markdown]
# select specific column using brackets

# %%
df2['radius_se']
# Out:
# 0      1.0950
# 1      0.5435
# 2      0.7456
# 3      0.4956
# 4      0.7572
#         ...
# 564    1.1760
# 565    0.7655
# 566    0.4564
# 567    0.7260
# 568    0.3857
# Name: radius_se, Length: 569, dtype: float64

# %% [markdown]
# select specific column using dot lotation

# %%
df2.iloc[:, 0:3]
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean
# 0                      1        17.99         10.38
# 1                      1        20.57         17.77
# 2                      1        19.69         21.25
# 3                      1        11.42         20.38
# 4                      1        20.29         14.34
# ..                   ...          ...           ...
# 564                    1        21.56         22.39
# 565                    1        20.13         28.25
# 566                    1        16.60         28.08
# 567                    1        20.60         29.33
# 568                    0         7.76         24.54
#
# [569 rows x 3 columns]

# %% [markdown]
# # **PART5**

# %% [markdown]
# count distinct values - descending (desc)

# %%
df2['area_se'].value_counts()
# Out:
# 16.97    3
# 17.67    3
# 16.64    3
# 18.54    3
# 20.98    2
#         ..
# 26.43    1
# 22.77    1
# 40.98    1
# 81.46    1
# 19.15    1
# Name: area_se, Length: 528, dtype: int64

# %% [markdown]
# count distinct values - ascending (asc)

# %%
df2['area_se'].value_counts(ascending=True)
# Out:
# 153.40    1
# 14.00     1
# 77.02     1
# 39.06     1
# 17.72     1
#          ..
# 15.24     2
# 16.97     3
# 16.64     3
# 18.54     3
# 17.67     3
# Name: area_se, Length: 528, dtype: int64

# %% [markdown]
# without NaN

# %%
df2['area_se'].value_counts(dropna=False)
# Out:
# 16.97    3
# 17.67    3
# 16.64    3
# 18.54    3
# 20.98    2
#         ..
# 26.43    1
# 22.77    1
# 40.98    1
# 81.46    1
# 19.15    1
# Name: area_se, Length: 528, dtype: int64

# %% [markdown]
# get relative frequency - percentage

# %%
df2['area_se'].value_counts(normalize=True)
# Out:
# 16.97    0.005272
# 17.67    0.005272
# 16.64    0.005272
# 18.54    0.005272
# 20.98    0.003515
#            ...
# 26.43    0.001757
# 22.77    0.001757
# 40.98    0.001757
# 81.46    0.001757
# 19.15    0.001757
# Name: area_se, Length: 528, dtype: float64

# %% [markdown]
# get specific item count

# %%
df2['area_se'].value_counts()[16.97]
# Out:
# 3

# %% [markdown]
# count unique values - size

# %%
df2.groupby('area_se').size()
# Out:
# area_se
# 6.802      1
# 7.228      1
# 7.254      1
# 7.326      1
# 8.205      1
#           ..
# 199.700    1
# 224.100    1
# 233.000    1
# 525.600    1
# 542.200    1
# Length: 528, dtype: int64

# %% [markdown]
# count unique values - count

# %%
df2.groupby('area_se').count()
# Out:
#          diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# area_se
# 6.802                      1            1             1               1
# 7.228                      1            1             1               1
# 7.254                      1            1             1               1
# 7.326                      1            1             1               1
# 8.205                      1            1             1               1
# ...                      ...          ...           ...             ...
# 199.700                    1            1             1               1
# 224.100                    1            1             1               1
# 233.000                    1            1             1               1
# 525.600                    1            1             1               1
# 542.200                    1            1             1               1
#
#          area_mean  ...  compactness_worst  concavity_worst  \
# area_se             ...
# ...

# %% [markdown]
# get a count of all columns across columns

# %%
df2.apply(pd.value_counts)
# Out:
#              diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0.000000                   357.0          NaN           NaN             NaN
# 0.000692                     NaN          NaN           NaN             NaN
# 0.000793                     NaN          NaN           NaN             NaN
# 0.000895                     NaN          NaN           NaN             NaN
# 0.000950                     NaN          NaN           NaN             NaN
# ...                          ...          ...           ...             ...
# 3143.000000                  NaN          NaN           NaN             NaN
# 3216.000000                  NaN          NaN           NaN             NaN
# 3234.000000                  NaN          NaN           NaN             NaN
# 3432.000000                  NaN          NaN           NaN             NaN
# 4254.000000                  NaN          NaN           NaN             NaN
#
# ...

# %% [markdown]
# # **PART6**

# %% [markdown]
# add column from list

# %%
new = ['one1', 'one2', 'one3', 'one4'] # it must be size of the table
df2['new'] = new
# Out:
# d

# %% [markdown]
# add default values

# %%
df2['nothingnew'] = [True] * len(df2)
df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# add NaN value

# %%
df2['nothingold'] = [np.nan] * len(df2)
df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# add column with insert() - allows position

# %%
df2.insert(1, "new", [True]*len(df2), True) # index, header, whats inside, allow duplicates
df2
# Out:
#      diagnosis(1=m, 0=b)   new  radius_mean  texture_mean  perimeter_mean  \
# 0                      1  True        17.99         10.38          122.80
# 1                      1  True        20.57         17.77          132.90
# 2                      1  True        19.69         21.25          130.00
# 3                      1  True        11.42         20.38           77.58
# 4                      1  True        20.29         14.34          135.10
# ..                   ...   ...          ...           ...             ...
# 564                    1  True        21.56         22.39          142.00
# 565                    1  True        20.13         28.25          131.20
# 566                    1  True        16.60         28.08          108.30
# 567                    1  True        20.60         29.33          140.10
# 568                    0  True         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %% [markdown]
# add column with .assign() - creates new df

# %%
df3 = df2.assign(Horse=[False]*len(df2))
df3
# Out:
#      diagnosis(1=m, 0=b)   new  radius_mean  texture_mean  perimeter_mean  \
# 0                      1  True        17.99         10.38          122.80
# 1                      1  True        20.57         17.77          132.90
# 2                      1  True        19.69         21.25          130.00
# 3                      1  True        11.42         20.38           77.58
# 4                      1  True        20.29         14.34          135.10
# ..                   ...   ...          ...           ...             ...
# 564                    1  True        21.56         22.39          142.00
# 565                    1  True        20.13         28.25          131.20
# 566                    1  True        16.60         28.08          108.30
# 567                    1  True        20.60         29.33          140.10
# 568                    0  True         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
df2
# Out:
#      diagnosis(1=m, 0=b)   new  radius_mean  texture_mean  perimeter_mean  \
# 0                      1  True        17.99         10.38          122.80
# 1                      1  True        20.57         17.77          132.90
# 2                      1  True        19.69         21.25          130.00
# 3                      1  True        11.42         20.38           77.58
# 4                      1  True        20.29         14.34          135.10
# ..                   ...   ...          ...           ...             ...
# 564                    1  True        21.56         22.39          142.00
# 565                    1  True        20.13         28.25          131.20
# 566                    1  True        16.60         28.08          108.30
# 567                    1  True        20.60         29.33          140.10
# 568                    0  True         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %% [markdown]
# # **PART7**

# %% [markdown]
# remove column

# %%
df2.drop("area_mean", axis=1)
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df2 # its still on place
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df2.drop("area_mean", axis=1, inplace=True) # it deletes permanently

# %% [markdown]
# remove row

# %%
df2.drop(3) # axis by default is 0
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 4                      1        20.29         14.34          135.10
# 5                      1        12.45         15.70           82.57
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# # **PART8**

# %% [markdown]
# grab row method 1 location

# %%
df2.loc[2]
# Out:
# diagnosis(1=m, 0=b)           1.000000
# radius_mean                  19.690000
# texture_mean                 21.250000
# perimeter_mean              130.000000
# smoothness_mean               0.109600
# compactness_mean              0.159900
# concavity_mean                0.197400
# concave points_mean           0.127900
# symmetry_mean                 0.206900
# fractal_dimension_mean        0.059990
# radius_se                     0.745600
# texture_se                    0.786900
# perimeter_se                  4.585000
# area_se                      94.030000
# smoothness_se                 0.006150
# compactness_se                0.040060
# concavity_se                  0.038320
# concave points_se             0.020580
# symmetry_se                   0.022500
# fractal_dimension_se          0.004571
# radius_worst                 23.570000
# texture_worst                25.530000
# perimeter_worst             152.500000
# area_worst                 1709.000000
# ...

# %% [markdown]
# grab row method 2 index location

# %%
df2.iloc[1]
# Out:
# diagnosis(1=m, 0=b)           1.000000
# radius_mean                  20.570000
# texture_mean                 17.770000
# perimeter_mean              132.900000
# smoothness_mean               0.084740
# compactness_mean              0.078640
# concavity_mean                0.086900
# concave points_mean           0.070170
# symmetry_mean                 0.181200
# fractal_dimension_mean        0.056670
# radius_se                     0.543500
# texture_se                    0.733900
# perimeter_se                  3.398000
# area_se                      74.080000
# smoothness_se                 0.005225
# compactness_se                0.013080
# concavity_se                  0.018600
# concave points_se             0.013400
# symmetry_se                   0.013890
# fractal_dimension_se          0.003532
# radius_worst                 24.990000
# texture_worst                23.410000
# perimeter_worst             158.800000
# area_worst                 1956.000000
# ...

# %% [markdown]
# specific points(row and column)
#  df.loc['row', 'column']

# %%
df2.loc[1, 'radius_mean']
# Out:
# 20.57

# %% [markdown]
# subsets
# df2.loc[['row', 'row'], ['column', 'column']]

# %%
df2.loc[[1, 3], ['area_worst', 'radius_mean']]
# Out:
#    area_worst  radius_mean
# 1      1956.0        20.57
# 3       567.7        11.42

# %% [markdown]
# # **PART9**

# %% [markdown]
# conditional selection
# # >, < , =, >=, <=

# %%
df2 == "BROWN" # condition if it equals BROWN
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                  False        False         False           False
# 1                  False        False         False           False
# 2                  False        False         False           False
# 3                  False        False         False           False
# 4                  False        False         False           False
# ..                   ...          ...           ...             ...
# 564                False        False         False           False
# 565                False        False         False           False
# 566                False        False         False           False
# 567                False        False         False           False
# 568                False        False         False           False
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0        False            False             False           False
# ...

# %% [markdown]
# returns dataframe with data

# %%
df2[df2 == 1]
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                    1.0          NaN           NaN             NaN
# 1                    1.0          NaN           NaN             NaN
# 2                    1.0          NaN           NaN             NaN
# 3                    1.0          NaN           NaN             NaN
# 4                    1.0          NaN           NaN             NaN
# ..                   ...          ...           ...             ...
# 564                  1.0          NaN           NaN             NaN
# 565                  1.0          NaN           NaN             NaN
# 566                  1.0          NaN           NaN             NaN
# 567                  1.0          NaN           NaN             NaN
# 568                  NaN          NaN           NaN             NaN
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0          NaN              NaN               NaN             NaN
# ...

# %% [markdown]
# run them on a column

# %%
df2[df2 == "BROWN"]["texture_mean"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 564   NaN
# 565   NaN
# 566   NaN
# 567   NaN
# 568   NaN
# Name: texture_mean, Length: 569, dtype: float64

# %% [markdown]
# return multiple columns

# %%
df2[df2 == "BROWN"][["texture_mean", 'radius_mean']]
# Out:
#      texture_mean  radius_mean
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ..            ...          ...
# 564           NaN          NaN
# 565           NaN          NaN
# 566           NaN          NaN
# 567           NaN          NaN
# 568           NaN          NaN
#
# [569 rows x 2 columns]

# %%
df2[df2 > 10][["texture_mean", 'radius_mean']]
# Out:
#      texture_mean  radius_mean
# 0           10.38        17.99
# 1           17.77        20.57
# 2           21.25        19.69
# 3           20.38        11.42
# 4           14.34        20.29
# ..            ...          ...
# 564         22.39        21.56
# 565         28.25        20.13
# 566         28.08        16.60
# 567         29.33        20.60
# 568         24.54          NaN
#
# [569 rows x 2 columns]

# %% [markdown]
# # **PART10**

# %% [markdown]
# multiple conditional AND

# %%
df2[(df2['texture_mean'] == 17.77) & (df2['radius_mean'] == 20.57)]
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1                    1        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 1         0.1812  ...         24.99          23.41            158.8
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 1      1956.0            0.1238             0.1866           0.2416
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 1                 0.186           0.275                  0.08902
#
# [1 rows x 31 columns]

# %% [markdown]
# get length

# %%
len(df2[(df2['texture_mean'] == 17.77) & (df2['radius_mean'] == 20.57)])
# Out:
# 1

# %% [markdown]
# multiple conditional OR

# %%
df2[(df2['texture_mean'] == 17.77) | (df2['radius_mean'] == 20.57)]
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1                    1        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 1         0.1812  ...         24.99          23.41            158.8
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 1      1956.0            0.1238             0.1866           0.2416
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 1                 0.186           0.275                  0.08902
#
# [1 rows x 31 columns]

# %% [markdown]
# get length

# %%
len(df2[(df2['texture_mean'] == 17.77) | (df2['radius_mean'] == 20.57)])
# Out:
# 1

# %% [markdown]
# return specific column

# %%
df2[(df2['texture_mean'] == 17.77) & (df2['radius_mean'] == 20.57)]['radius_mean']
# Out:
# 1    20.57
# Name: radius_mean, dtype: float64

# %% [markdown]
# # **PART11**

# %% [markdown]
# create new column

# %%
df2["nothing"] = len(df2) * ["Dog1"]
df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# set index

# %%
df2.set_index("nothing") # permanently - inplace=True
# Out:
#          diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# nothing
# Dog1                       1        17.99         10.38          122.80
# Dog1                       1        20.57         17.77          132.90
# Dog1                       1        19.69         21.25          130.00
# Dog1                       1        11.42         20.38           77.58
# Dog1                       1        20.29         14.34          135.10
# ...                      ...          ...           ...             ...
# Dog1                       1        21.56         22.39          142.00
# Dog1                       1        20.13         28.25          131.20
# Dog1                       1        16.60         28.08          108.30
# Dog1                       1        20.60         29.33          140.10
# Dog1                       0         7.76         24.54           47.92
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# nothing
# ...

# %% [markdown]
# show dataframe

# %%
df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# reset index

# %%
df2.reset_index()
# Out:
#      index  diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0        0                    1        17.99         10.38          122.80
# 1        1                    1        20.57         17.77          132.90
# 2        2                    1        19.69         21.25          130.00
# 3        3                    1        11.42         20.38           77.58
# 4        4                    1        20.29         14.34          135.10
# ..     ...                  ...          ...           ...             ...
# 564    564                    1        21.56         22.39          142.00
# 565    565                    1        20.13         28.25          131.20
# 566    566                    1        16.60         28.08          108.30
# 567    567                    1        20.60         29.33          140.10
# 568    568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %% [markdown]
# drop column

# %%
df2.drop("nothing", axis=1)
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# # **PART12**

# %% [markdown]
# create dummy data

# %%
stuff = {'A': [1,2,3], "B": [4,np.nan,6], "C": [7,8,9], 'D': [10,11,12]}
df2 = pd.DataFrame(stuff)
df2
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %% [markdown]
# drop rows with null data

# %%
df2.dropna()
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 2  3  6.0  9  12

# %% [markdown]
# drop columns with null data

# %%
df2.dropna(axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %% [markdown]
# not permanent, inplace=False

# %%
df2
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %% [markdown]
# more than one? set threshold

# %%
df2.dropna(thresh=2, axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %% [markdown]
# replace things with fillna()

# %%
df2.fillna(value="Bob")
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  Bob  8  11
# 2  3  6.0  9  12

# %% [markdown]
# use math functions

# %%
df2.fillna(value=df2['B'].mean())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  5.0  8  11
# 2  3  6.0  9  12

# %% [markdown]
# use min max

# %%
df2.fillna(value=df2['B'].min())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  4.0  8  11
# 2  3  6.0  9  12

# %%
df2.fillna(value=df2['B'].max())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  6.0  8  11
# 2  3  6.0  9  12

# %% [markdown]
# # **PART13**

# %%
stuff = {
    'Corporation': ['Apple', 'Google', 'Meta', 'Apple', 'Google', 'Meta'],
    'Employees': ['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary': [200, 220, 190, 130, 120, 150]

}
df3 = pd.DataFrame(stuff)
df3
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %% [markdown]
# group by corporation - to get object location in memory

# %%
company = df3.groupby('Corporation')
company

# %% [markdown]
# sum

# %%
company.sum()
# Out:
# <ipython-input-83-924a94547f2e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   company.sum()
#              Salary
# Corporation
# Apple           330
# Google          340
# Meta            340

# %% [markdown]
# mean

# %%
company.mean()
# Out:
# <ipython-input-84-5a98313652ee>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   company.mean()
#              Salary
# Corporation
# Apple         165.0
# Google        170.0
# Meta          170.0

# %% [markdown]
# max min

# %%
company.min()
# Out:
#             Employees  Salary
# Corporation
# Apple            Beth     130
# Google          April     120
# Meta            Steph     150

# %% [markdown]
# standard deviation

# %%
company.std()
# Out:
# <ipython-input-86-71b896b2e693>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   company.std()
#                 Salary
# Corporation
# Apple        49.497475
# Google       70.710678
# Meta         28.284271

# %% [markdown]
# variance

# %%
company.var()
# Out:
# <ipython-input-87-fbd8e774d961>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   company.var()
#              Salary
# Corporation
# Apple        2450.0
# Google       5000.0
# Meta          800.0

# %% [markdown]
# count

# %%
company.count()
# Out:
#              Employees  Salary
# Corporation
# Apple                2       2
# Google               2       2
# Meta                 2       2

# %% [markdown]
# describe

# %%
company.describe()
# Out:
#             Salary
#              count   mean        std    min    25%    50%    75%    max
# Corporation
# Apple          2.0  165.0  49.497475  130.0  147.5  165.0  182.5  200.0
# Google         2.0  170.0  70.710678  120.0  145.0  170.0  195.0  220.0
# Meta           2.0  170.0  28.284271  150.0  160.0  170.0  180.0  190.0

# %% [markdown]
# # **PART14**

# %%
df2
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# grab a specific column

# %%
df2["radius_mean"]
# Out:
# 0      17.99
# 1      20.57
# 2      19.69
# 3      11.42
# 4      20.29
#        ...
# 564    21.56
# 565    20.13
# 566    16.60
# 567    20.60
# 568     7.76
# Name: radius_mean, Length: 569, dtype: float64

# %% [markdown]
# count values

# %%
df2["radius_mean"].value_counts()
# Out:
# 12.34    4
# 11.71    3
# 12.46    3
# 13.05    3
# 10.26    3
#         ..
# 12.23    1
# 14.45    1
# 19.18    1
# 18.08    1
# 7.76     1
# Name: radius_mean, Length: 456, dtype: int64

# %% [markdown]
# pass as DataFrame

# %%
pd.DataFrame(df2["radius_mean"].value_counts()).head()
# Out:
#        radius_mean
# 12.34            4
# 11.71            3
# 12.46            3
# 13.05            3
# 10.26            3

# %% [markdown]
# grab uniques

# %%
df2["radius_mean"].unique()
# Out:
# array([17.99 , 20.57 , 19.69 , 11.42 , 20.29 , 12.45 , 18.25 , 13.71 ,
#        13.   , 12.46 , 16.02 , 15.78 , 19.17 , 15.85 , 13.73 , 14.54 ,
#        14.68 , 16.13 , 19.81 , 13.54 , 13.08 ,  9.504, 15.34 , 21.16 ,
#        16.65 , 17.14 , 14.58 , 18.61 , 15.3  , 17.57 , 18.63 , 11.84 ,
#        17.02 , 19.27 , 16.74 , 14.25 , 13.03 , 14.99 , 13.48 , 13.44 ,
#        10.95 , 19.07 , 13.28 , 13.17 , 18.65 ,  8.196, 12.05 , 13.49 ,
#        11.76 , 13.64 , 11.94 , 18.22 , 15.1  , 11.52 , 19.21 , 14.71 ,
#        13.05 ,  8.618, 10.17 ,  8.598,  9.173, 12.68 , 14.78 ,  9.465,
#        11.31 ,  9.029, 12.78 , 18.94 ,  8.888, 17.2  , 13.8  , 12.31 ,
#        16.07 , 13.53 , 18.05 , 20.18 , 12.86 , 11.45 , 13.34 , 25.22 ,
#        19.1  , 12.   , 18.46 , 14.48 , 19.02 , 12.36 , 14.64 , 14.62 ,
#        15.37 , 13.27 , 13.45 , 15.06 , 20.26 , 12.18 ,  9.787, 11.6  ,
#        14.42 , 13.61 ,  6.981,  9.876, 10.49 , 13.11 , 11.64 , 22.27 ,
# ...

# %%
pd.DataFrame(df2["radius_mean"].unique()).head(50)
# Out:
#          0
# 0   17.990
# 1   20.570
# 2   19.690
# 3   11.420
# 4   20.290
# 5   12.450
# 6   18.250
# 7   13.710
# 8   13.000
# 9   12.460
# 10  16.020
# 11  15.780
# 12  19.170
# 13  15.850
# 14  13.730
# 15  14.540
# 16  14.680
# 17  16.130
# 18  19.810
# 19  13.540
# 20  13.080
# 21   9.504
# 22  15.340
# 23  21.160
# 24  16.650
# 25  17.140
# 26  14.580
# 27  18.610
# 28  15.300
# 29  17.570
# 30  18.630
# 31  11.840
# 32  17.020
# 33  19.270
# 34  16.740
# 35  14.250
# 36  13.030
# 37  14.990
# 38  13.480
# 39  13.440
# 40  10.950
# 41  19.070
# 42  13.280
# 43  13.170
# 44  18.650
# 45   8.196
# 46  12.050
# 47  13.490
# 48  11.760
# 49  13.640

# %% [markdown]
# # **PART15**

# %%
df3
# Out:
#   Corporation Employees       Salary
# 0       Apple      John  200,000,000
# 1      Google     April  220,000,000
# 2        Meta       Wes  190,000,000
# 3       Apple      Beth  130,000,000
# 4      Google    Justin  120,000,000
# 5        Meta     Steph  150,000,000

# %% [markdown]
# create a function

# %%
def times1000(x):
  return format(x * 1000, ',d')

# %% [markdown]
# use apply function

# %%
df3['Salary'].apply(times1000)
# Out:
# 0    200,000
# 1    220,000
# 2    190,000
# 3    130,000
# 4    120,000
# 5    150,000
# Name: Salary, dtype: object

# %% [markdown]
# make it into a dataframe

# %%
pd.DataFrame(df3['Salary'].apply(times1000))
# Out:
#     Salary
# 0  200,000
# 1  220,000
# 2  190,000
# 3  130,000
# 4  120,000
# 5  150,000

# %% [markdown]
# add elder last name

# %%
def namer(x):
  if x == "John":
    return "John Elder"
  else:
    return x

df3['Employees'].apply(namer)
# Out:
# 0    John Elder
# 1         April
# 2           Wes
# 3          Beth
# 4        Justin
# 5         Steph
# Name: Employees, dtype: object

# %% [markdown]
# use lambda

# %%
df3['Salary'].apply(lambda x: x * 1000)
# Out:
# 0    200000
# 1    220000
# 2    190000
# 3    130000
# 4    120000
# 5    150000
# Name: Salary, dtype: int64

# %% [markdown]
# # **PART16**

# %% [markdown]
# append to current DF

# %%
df3["Salary"] = df3['Salary'].apply(times1000)
df3
# Out:
#   Corporation Employees   Salary
# 0       Apple      John  200,000
# 1      Google     April  220,000
# 2        Meta       Wes  190,000
# 3       Apple      Beth  130,000
# 4      Google    Justin  120,000
# 5        Meta     Steph  150,000

# %% [markdown]
# function on multiple columns

# %%
def namer(x):
  return "Company: " + x

# %% [markdown]
# apply to two columns

# %%
df3[['Corporation', 'Employees']].apply(namer)
# Out:
#        Corporation        Employees
# 0   Company: Apple    Company: John
# 1  Company: Google   Company: April
# 2    Company: Meta     Company: Wes
# 3   Company: Apple    Company: Beth
# 4  Company: Google  Company: Justin
# 5    Company: Meta   Company: Steph

# %% [markdown]
# append to current Dataframe

# %%
df3[['Corporation', 'Employees']] = df3[['Corporation', 'Employees']].apply(namer)
df3
# Out:
#        Corporation        Employees  Salary
# 0   Company: Apple    Company: John     200
# 1  Company: Google   Company: April     220
# 2    Company: Meta     Company: Wes     190
# 3   Company: Apple    Company: Beth     130
# 4  Company: Google  Company: Justin     120
# 5    Company: Meta   Company: Steph     150

# %% [markdown]
# # **PART17**

# %% [markdown]
# sort salaries from lowest to highest

# %%
df3.sort_values("Salary")
# Out:
#        Corporation        Employees  Salary
# 4  Company: Google  Company: Justin     120
# 3   Company: Apple    Company: Beth     130
# 5    Company: Meta   Company: Steph     150
# 2    Company: Meta     Company: Wes     190
# 0   Company: Apple    Company: John     200
# 1  Company: Google   Company: April     220

# %% [markdown]
# sort salaries from highest to lowest

# %%
df3.sort_values("Salary", ascending=False)
# Out:
#        Corporation        Employees  Salary
# 1  Company: Google   Company: April     220
# 0   Company: Apple    Company: John     200
# 2    Company: Meta     Company: Wes     190
# 5    Company: Meta   Company: Steph     150
# 3   Company: Apple    Company: Beth     130
# 4  Company: Google  Company: Justin     120

# %% [markdown]
# not permanent without inplace = True

# %%
df3.sort_values("Salary", inplace=True)
df3
# Out:
#        Corporation        Employees  Salary
# 4  Company: Google  Company: Justin     120
# 3   Company: Apple    Company: Beth     130
# 5    Company: Meta   Company: Steph     150
# 2    Company: Meta     Company: Wes     190
# 0   Company: Apple    Company: John     200
# 1  Company: Google   Company: April     220

# %% [markdown]
# sort strings alphabetically

# %%
df3.sort_values("Corporation")
# Out:
#        Corporation        Employees  Salary
# 3   Company: Apple    Company: Beth     130
# 0   Company: Apple    Company: John     200
# 4  Company: Google  Company: Justin     120
# 1  Company: Google   Company: April     220
# 5    Company: Meta   Company: Steph     150
# 2    Company: Meta     Company: Wes     190

# %% [markdown]
# # **PART18**

# %% [markdown]
# histograms with mathplotlib

# %%
import matplotlib.pyplot as plt
from numpy.random import randn

# %% [markdown]
# create a dataframe

# %%
df4 = pd.DataFrame(randn(100, 4), columns=['Mon', 'Tues', "Wed", 'Thur'])
df4
# Out:
#          Mon      Tues       Wed      Thur
# 0  -2.039432  0.809603 -0.679096  0.194668
# 1  -0.175309  0.898837 -0.541917 -0.336607
# 2  -1.057500  0.709624  1.142711  2.671080
# 3  -1.261034 -0.573918  0.037506 -0.348558
# 4   0.263774 -0.247240 -1.094774 -1.196156
# ..       ...       ...       ...       ...
# 95  0.698917 -0.277717  0.421171  0.810661
# 96  0.511164 -0.338481 -0.306764  1.326620
# 97 -0.546664  0.589965 -1.166740  0.742324
# 98  0.428453 -1.226238  0.752538 -0.383901
# 99 -0.206412 -1.194393 -1.139741 -0.942333
#
# [100 rows x 4 columns]

# %% [markdown]
# histogram

# %%
df4['Wed'].hist()
# Out:
# <Axes: >

# %% [markdown]
# histogram with smaller bins, 50, 20

# %%
df4['Wed'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# another way without grid bars

# %%
df4['Wed'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df4['Wed'].hist(bins=50, grid=False)
# Out:
# <Axes: >

# %%
df4['Wed'].hist(bins=50, legend=True)
# Out:
# <Axes: >
